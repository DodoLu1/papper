# %%
import numpy as np
import cv2
import glob
import os

# %%
imagelist= sorted(glob.glob('D:/openpose_data/揮手測試/揮手_左右/' + '揮手圖片檔00000*.jpg'))

# %%
len(imagelist)
# Out:
# 543

# %%
imagelist= sorted(glob.glob('D:/openpose_data/UT_Kinect/RGB/s01_e01/' + 'colorImg*.jpg'))

# %%
imagelist= sorted(glob.glob('D:/openpose_data/UT_Kinect/RGB/s01_e02/colorImg[0-9][0-9][0-9].jpg'))

# %%
imagelist_2= sorted(glob.glob('D:/openpose_data/UT_Kinect/RGB/s01_e02/colorImg[0-9][0-9][0-9][0-9].jpg'))

# %%
df = imagelist+imagelist_2

# %%
imagelist= glob.glob(os.path.join("D:/openpose_data/UT_Kinect/RGB/s01_e01", "*[g][2-3][0-9][0-9].jpg"))

# %%
len(imagelist)
# Out:
# 543

# %%
imagelist[0:379]
# Out:
# ['D:/openpose_data/揮手測試\\揮手圖片檔00000101.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000102.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000103.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000104.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000105.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000106.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000107.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000108.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000109.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000110.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000111.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000112.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000113.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000114.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000115.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000116.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000117.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000118.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000119.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000120.jpg',
#  'D:/openpose_data/揮手測試\\揮手圖片檔00000121.jpg',
# ...

# %%
import glob
cv_img = []
for img in imagelist:                  
    n= cv2.imread(img)         
    cv2.imshow(img, n)
    cv2.waitKey(100000)
    cv2.destroyAllWindows()    
    #cv_img.append(n)

# %%
img = cv2.imread(imagelist, 0)
 
cv2.imshow(imagelist, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\DodoLu\Desktop\paper\openpose\python\test.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DodoLu/Desktop/paper/openpose/python/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> img = cv2.imread(imagelist, 0)
#       <a href='vscode-notebook-cell:/c%3A/Users/DodoLu/Desktop/paper/openpose/python/test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> cv2.imshow(imagelist, img)
#       <a href='vscode-notebook-cell:/c%3A/Users/DodoLu/Desktop/paper/openpose/python/test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> cv2.waitKey(0)
#
# TypeError: Can't convert object to 'str' for 'filename'

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
# 读取图片
import matplotlib.image as mpimg
# 显示图片
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import pandas as pd

path=r"E:\study\data\datanumber"

X_train=[]
Y_train=[]
X_test=[]
Y_test=[]

# 加载1到9，每个数字里面的500张图片 小于480用于训练，大于480用于测试
# 并把二维数组转为一维数组
for i in range(1,9):
    for j in range(1,501):
        if j<480:
            X_train.append(mpimg.imread(path+"\\%d\\%d_%d.bmp" %(i,i,j)).reshape(-1))
            Y_train.append(i)
        else:
            X_test.append(mpimg.imread(path+"\\%d\\%d_%d.bmp" %(i,i,j)).reshape(-1))
            Y_test.append(i)
# 转化成numpy类型的数组
X_train=np.array(X_train)
Y_train=np.array(Y_train)
X_test=np.array(X_test)
Y_test=np.array(Y_test)
